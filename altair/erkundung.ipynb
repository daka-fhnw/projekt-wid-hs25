# %% [markdown]
# # Erkundung der Daten
#
# In diesem Jupyter Notebook wird die Erkundung der Daten vorbereitet:
# Für verschiedene Zeiträume und Filterkriterien soll die Anzahl Passanten pro Standort dargestellt werden.
#
# Einerseits werden hier die pandas-Funktionen vorbereitet für die Datenabfrage und andererseits die "spec" für die Darstellung des Diagrammes.

# %% [markdown]
# ## Vorbereiten der Daten

# %% [markdown]
# ### Daten aus CSV laden

# %%
import pandas as pd

data = pd.read_csv('../daten/Gesamtdatensatz.csv')
data
# Out:
#                    timestamp  location_id           location_name  \
# 0       2021-09-28T22:00:00Z          329  Bahnhofstrasse (Mitte)
# 1       2021-09-28T22:00:00Z          331   Bahnhofstrasse (Nord)
# 2       2021-09-28T22:00:00Z          330    Bahnhofstrasse (Süd)
# 3       2021-09-28T22:00:00Z          670        Lintheschergasse
# 4       2021-09-28T23:00:00Z          329  Bahnhofstrasse (Mitte)
# ...                      ...          ...                     ...
# 134435  2025-07-30T06:00:00Z          670        Lintheschergasse
# 134436  2025-07-30T07:00:00Z          329  Bahnhofstrasse (Mitte)
# 134437  2025-07-30T07:00:00Z          331   Bahnhofstrasse (Nord)
# 134438  2025-07-30T07:00:00Z          330    Bahnhofstrasse (Süd)
# 134439  2025-07-30T07:00:00Z          670        Lintheschergasse
#
#            ltr_label     rtl_label  weather_condition  temperature  \
# 0       Hauptbahnhof   Bürkliplatz             cloudy        13.51
# 1        Bürkliplatz  Hauptbahnhof             cloudy        13.51
# 2        Bürkliplatz  Hauptbahnhof             cloudy        13.51
# 3       Hauptbahnhof  Uraniastraße             cloudy        13.51
# 4       Hauptbahnhof   Bürkliplatz             cloudy        13.46
# ...              ...           ...                ...          ...
# 134435  Hauptbahnhof  Uraniastraße  partly-cloudy-day        14.20
# 134436  Hauptbahnhof   Bürkliplatz             cloudy        16.20
# 134437   Bürkliplatz  Hauptbahnhof             cloudy        16.20
# 134438   Bürkliplatz  Hauptbahnhof             cloudy        16.20
# 134439  Hauptbahnhof  Uraniastraße             cloudy        16.20
#
#         pedestrians_count  unverified collection_type  ...  \
# 0                     151       False        measured  ...
# 1                     118       False        measured  ...
# 2                     203       False        measured  ...
# 3                       0       False             NaN  ...
# 4                      19       False        measured  ...
# ...                   ...         ...             ...  ...
# 134435                  0        True             NaN  ...
# 134436                  0        True             NaN  ...
# 134437                  0        True             NaN  ...
# 134438                  0        True             NaN  ...
# 134439                  0        True             NaN  ...
#
#         zone_3_pedestrians_count  zone_3_ltr_pedestrians_count  \
# 0                           47.0                          30.0
# 1                           40.0                          10.0
# 2                           64.0                          11.0
# 3                            NaN                           NaN
# 4                           11.0                           1.0
# ...                          ...                           ...
# 134435                       NaN                           NaN
# 134436                       0.0                           0.0
# 134437                       0.0                           0.0
# 134438                       0.0                           0.0
# 134439                       NaN                           NaN
#
#         zone_3_rtl_pedestrians_count  zone_3_adult_pedestrians_count  \
# 0                               17.0                            47.0
# 1                               30.0                            40.0
# 2                               53.0                            59.0
# 3                                NaN                             NaN
# 4                               10.0                            11.0
# ...                              ...                             ...
# 134435                           NaN                             NaN
# 134436                           0.0                             0.0
# 134437                           0.0                             0.0
# 134438                           0.0                             0.0
# 134439                           NaN                             NaN
#
#         zone_3_child_pedestrians_count  zone_99_pedestrians_count  \
# 0                                  0.0                        NaN
# 1                                  0.0                        NaN
# 2                                  5.0                        0.0
# 3                                  NaN                        NaN
# 4                                  0.0                        NaN
# ...                                ...                        ...
# 134435                             NaN                        NaN
# 134436                             0.0                        NaN
# 134437                             0.0                        NaN
# 134438                             0.0                        NaN
# 134439                             NaN                        NaN
#
#         zone_99_ltr_pedestrians_count  zone_99_rtl_pedestrians_count  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 0.0                            0.0
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 134435                            NaN                            NaN
# 134436                            NaN                            NaN
# 134437                            NaN                            NaN
# 134438                            NaN                            NaN
# 134439                            NaN                            NaN
#
#         zone_99_adult_pedestrians_count  zone_99_child_pedestrians_count
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   0.0                              0.0
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
# ...                                 ...                              ...
# 134435                              NaN                              NaN
# 134436                              NaN                              NaN
# 134437                              NaN                              NaN
# 134438                              NaN                              NaN
# 134439                              NaN                              NaN
#
# [134440 rows x 38 columns]

# %% [markdown]
# ### Nach Datumsbereich filtern

# %%
datum_von = '2024-01-01'
datum_bis = '2024-12-31'
data = data[(data['timestamp'] >= datum_von) & (data['timestamp'] <= datum_bis)]
data
# Out:
#                    timestamp  location_id           location_name  \
# 79112   2024-01-01T00:00:00Z          329  Bahnhofstrasse (Mitte)
# 79113   2024-01-01T00:00:00Z          331   Bahnhofstrasse (Nord)
# 79114   2024-01-01T00:00:00Z          330    Bahnhofstrasse (Süd)
# 79115   2024-01-01T00:00:00Z          670        Lintheschergasse
# 79116   2024-01-01T01:00:00Z          329  Bahnhofstrasse (Mitte)
# ...                      ...          ...                     ...
# 114147  2024-12-30T22:00:00Z          670        Lintheschergasse
# 114148  2024-12-30T23:00:00Z          329  Bahnhofstrasse (Mitte)
# 114149  2024-12-30T23:00:00Z          331   Bahnhofstrasse (Nord)
# 114150  2024-12-30T23:00:00Z          330    Bahnhofstrasse (Süd)
# 114151  2024-12-30T23:00:00Z          670        Lintheschergasse
#
#            ltr_label     rtl_label    weather_condition  temperature  \
# 79112   Hauptbahnhof   Bürkliplatz  partly-cloudy-night          4.0
# 79113    Bürkliplatz  Hauptbahnhof  partly-cloudy-night          4.0
# 79114    Bürkliplatz  Hauptbahnhof  partly-cloudy-night          4.0
# 79115   Hauptbahnhof  Uraniastraße  partly-cloudy-night          4.0
# 79116   Hauptbahnhof   Bürkliplatz  partly-cloudy-night          4.0
# ...              ...           ...                  ...          ...
# 114147  Hauptbahnhof  Uraniastraße               cloudy         -3.1
# 114148  Hauptbahnhof   Bürkliplatz               cloudy         -2.0
# 114149   Bürkliplatz  Hauptbahnhof               cloudy         -2.0
# 114150   Bürkliplatz  Hauptbahnhof               cloudy         -2.0
# 114151  Hauptbahnhof  Uraniastraße               cloudy         -2.0
#
#         pedestrians_count  unverified collection_type  ...  \
# 79112                5289       False        measured  ...
# 79113                5284       False        measured  ...
# 79114                3572       False        measured  ...
# 79115                   0       False             NaN  ...
# 79116                1200       False        measured  ...
# ...                   ...         ...             ...  ...
# 114147                 29       False        measured  ...
# 114148                139       False        measured  ...
# 114149                 63       False        measured  ...
# 114150                 97       False        measured  ...
# 114151                  9       False        measured  ...
#
#         zone_3_pedestrians_count  zone_3_ltr_pedestrians_count  \
# 79112                     1957.0                        1650.0
# 79113                     2471.0                         122.0
# 79114                     1871.0                         136.0
# 79115                        NaN                           NaN
# 79116                      379.0                         276.0
# ...                          ...                           ...
# 114147                       NaN                           NaN
# 114148                      30.0                          10.0
# 114149                      33.0                          15.0
# 114150                      25.0                           9.0
# 114151                       NaN                           NaN
#
#         zone_3_rtl_pedestrians_count  zone_3_adult_pedestrians_count  \
# 79112                          307.0                          1945.0
# 79113                         2349.0                          2468.0
# 79114                         1735.0                          1868.0
# 79115                            NaN                             NaN
# 79116                          103.0                           379.0
# ...                              ...                             ...
# 114147                           NaN                             NaN
# 114148                          20.0                            28.0
# 114149                          18.0                            33.0
# 114150                          16.0                            25.0
# 114151                           NaN                             NaN
#
#         zone_3_child_pedestrians_count  zone_99_pedestrians_count  \
# 79112                             12.0                        NaN
# 79113                              3.0                        NaN
# 79114                              3.0                        NaN
# 79115                              NaN                        NaN
# 79116                              0.0                        NaN
# ...                                ...                        ...
# 114147                             NaN                        NaN
# 114148                             2.0                        NaN
# 114149                             0.0                        NaN
# 114150                             0.0                        NaN
# 114151                             NaN                        NaN
#
#         zone_99_ltr_pedestrians_count  zone_99_rtl_pedestrians_count  \
# 79112                             NaN                            NaN
# 79113                             NaN                            NaN
# 79114                             NaN                            NaN
# 79115                             NaN                            NaN
# 79116                             NaN                            NaN
# ...                               ...                            ...
# 114147                            NaN                            NaN
# 114148                            NaN                            NaN
# 114149                            NaN                            NaN
# 114150                            NaN                            NaN
# 114151                            NaN                            NaN
#
#         zone_99_adult_pedestrians_count  zone_99_child_pedestrians_count
# 79112                               NaN                              NaN
# 79113                               NaN                              NaN
# 79114                               NaN                              NaN
# 79115                               NaN                              NaN
# 79116                               NaN                              NaN
# ...                                 ...                              ...
# 114147                              NaN                              NaN
# 114148                              NaN                              NaN
# 114149                              NaN                              NaN
# 114150                              NaN                              NaN
# 114151                              NaN                              NaN
#
# [35040 rows x 38 columns]

# %% [markdown]
# ### Nach Stundenbereich filtern

# %%
stunde_von = 14
stunde_bis = 18
stunden = pd.to_datetime(data['timestamp']).dt.hour
data = data[(stunden >= stunde_von) & (stunden <= stunde_bis)]
data
# Out:
#                    timestamp  location_id           location_name  \
# 79168   2024-01-01T14:00:00Z          329  Bahnhofstrasse (Mitte)
# 79169   2024-01-01T14:00:00Z          331   Bahnhofstrasse (Nord)
# 79170   2024-01-01T14:00:00Z          330    Bahnhofstrasse (Süd)
# 79171   2024-01-01T14:00:00Z          670        Lintheschergasse
# 79172   2024-01-01T15:00:00Z          329  Bahnhofstrasse (Mitte)
# ...                      ...          ...                     ...
# 114127  2024-12-30T17:00:00Z          670        Lintheschergasse
# 114128  2024-12-30T18:00:00Z          329  Bahnhofstrasse (Mitte)
# 114129  2024-12-30T18:00:00Z          331   Bahnhofstrasse (Nord)
# 114130  2024-12-30T18:00:00Z          330    Bahnhofstrasse (Süd)
# 114131  2024-12-30T18:00:00Z          670        Lintheschergasse
#
#            ltr_label     rtl_label  weather_condition  temperature  \
# 79168   Hauptbahnhof   Bürkliplatz  partly-cloudy-day          7.0
# 79169    Bürkliplatz  Hauptbahnhof  partly-cloudy-day          7.0
# 79170    Bürkliplatz  Hauptbahnhof  partly-cloudy-day          7.0
# 79171   Hauptbahnhof  Uraniastraße  partly-cloudy-day          7.0
# 79172   Hauptbahnhof   Bürkliplatz  partly-cloudy-day          6.0
# ...              ...           ...                ...          ...
# 114127  Hauptbahnhof  Uraniastraße             cloudy         -2.0
# 114128  Hauptbahnhof   Bürkliplatz             cloudy         -2.0
# 114129   Bürkliplatz  Hauptbahnhof             cloudy         -2.0
# 114130   Bürkliplatz  Hauptbahnhof             cloudy         -2.0
# 114131  Hauptbahnhof  Uraniastraße             cloudy         -2.0
#
#         pedestrians_count  unverified collection_type  ...  \
# 79168                2088       False        measured  ...
# 79169                1909       False        measured  ...
# 79170                1647       False        measured  ...
# 79171                   0       False             NaN  ...
# 79172                2355       False        measured  ...
# ...                   ...         ...             ...  ...
# 114127               1802       False        measured  ...
# 114128               2743       False        measured  ...
# 114129               2891       False        measured  ...
# 114130                982       False        measured  ...
# 114131               1203       False        measured  ...
#
#         zone_3_pedestrians_count  zone_3_ltr_pedestrians_count  \
# 79168                      861.0                         297.0
# 79169                      733.0                         277.0
# 79170                      919.0                         525.0
# 79171                        NaN                           NaN
# 79172                      912.0                         278.0
# ...                          ...                           ...
# 114127                       NaN                           NaN
# 114128                    1213.0                         414.0
# 114129                    1106.0                         433.0
# 114130                     441.0                         206.0
# 114131                       NaN                           NaN
#
#         zone_3_rtl_pedestrians_count  zone_3_adult_pedestrians_count  \
# 79168                          564.0                           857.0
# 79169                          456.0                           731.0
# 79170                          394.0                           902.0
# 79171                            NaN                             NaN
# 79172                          634.0                           901.0
# ...                              ...                             ...
# 114127                           NaN                             NaN
# 114128                         799.0                          1207.0
# 114129                         673.0                          1104.0
# 114130                         235.0                           440.0
# 114131                           NaN                             NaN
#
#         zone_3_child_pedestrians_count  zone_99_pedestrians_count  \
# 79168                              4.0                        NaN
# 79169                              2.0                        NaN
# 79170                             17.0                        NaN
# 79171                              NaN                        NaN
# 79172                             11.0                        NaN
# ...                                ...                        ...
# 114127                             NaN                        NaN
# 114128                             6.0                        NaN
# 114129                             2.0                        NaN
# 114130                             1.0                        NaN
# 114131                             NaN                        NaN
#
#         zone_99_ltr_pedestrians_count  zone_99_rtl_pedestrians_count  \
# 79168                             NaN                            NaN
# 79169                             NaN                            NaN
# 79170                             NaN                            NaN
# 79171                             NaN                            NaN
# 79172                             NaN                            NaN
# ...                               ...                            ...
# 114127                            NaN                            NaN
# 114128                            NaN                            NaN
# 114129                            NaN                            NaN
# 114130                            NaN                            NaN
# 114131                            NaN                            NaN
#
#         zone_99_adult_pedestrians_count  zone_99_child_pedestrians_count
# 79168                               NaN                              NaN
# 79169                               NaN                              NaN
# 79170                               NaN                              NaN
# 79171                               NaN                              NaN
# 79172                               NaN                              NaN
# ...                                 ...                              ...
# 114127                              NaN                              NaN
# 114128                              NaN                              NaN
# 114129                              NaN                              NaN
# 114130                              NaN                              NaN
# 114131                              NaN                              NaN
#
# [7300 rows x 38 columns]

# %% [markdown]
# ### Nach Temperatur filtern

# %%
temperatur_von = 25
temperatur_bis = 30
data = data[(data['temperature'] >= temperatur_von) & (data['temperature'] <= temperatur_bis)]
data
# Out:
#                    timestamp  location_id           location_name  \
# 88388   2024-04-06T15:00:00Z          329  Bahnhofstrasse (Mitte)
# 88389   2024-04-06T15:00:00Z          331   Bahnhofstrasse (Nord)
# 88390   2024-04-06T15:00:00Z          330    Bahnhofstrasse (Süd)
# 88391   2024-04-06T15:00:00Z          670        Lintheschergasse
# 88392   2024-04-06T16:00:00Z          329  Bahnhofstrasse (Mitte)
# ...                      ...          ...                     ...
# 103183  2024-09-07T17:00:00Z          670        Lintheschergasse
# 103184  2024-09-07T18:00:00Z          329  Bahnhofstrasse (Mitte)
# 103185  2024-09-07T18:00:00Z          331   Bahnhofstrasse (Nord)
# 103186  2024-09-07T18:00:00Z          330    Bahnhofstrasse (Süd)
# 103187  2024-09-07T18:00:00Z          670        Lintheschergasse
#
#            ltr_label     rtl_label weather_condition  temperature  \
# 88388   Hauptbahnhof   Bürkliplatz         clear-day         25.0
# 88389    Bürkliplatz  Hauptbahnhof         clear-day         25.0
# 88390    Bürkliplatz  Hauptbahnhof         clear-day         25.0
# 88391   Hauptbahnhof  Uraniastraße         clear-day         25.0
# 88392   Hauptbahnhof   Bürkliplatz         clear-day         26.0
# ...              ...           ...               ...          ...
# 103183  Hauptbahnhof  Uraniastraße         clear-day         27.0
# 103184  Hauptbahnhof   Bürkliplatz       clear-night         25.0
# 103185   Bürkliplatz  Hauptbahnhof       clear-night         25.0
# 103186   Bürkliplatz  Hauptbahnhof       clear-night         25.0
# 103187  Hauptbahnhof  Uraniastraße       clear-night         25.0
#
#         pedestrians_count  unverified collection_type  ...  \
# 88388                6755       False        measured  ...
# 88389                5406       False        measured  ...
# 88390                4289       False        measured  ...
# 88391                2149       False        measured  ...
# 88392                5135       False        measured  ...
# ...                   ...         ...             ...  ...
# 103183                791       False        measured  ...
# 103184               2379       False        measured  ...
# 103185               2072       False        measured  ...
# 103186               1540       False        measured  ...
# 103187                380       False        measured  ...
#
#         zone_3_pedestrians_count  zone_3_ltr_pedestrians_count  \
# 88388                     2841.0                        1141.0
# 88389                     2598.0                         991.0
# 88390                     2268.0                        1058.0
# 88391                        NaN                           NaN
# 88392                     2277.0                         887.0
# ...                          ...                           ...
# 103183                       NaN                           NaN
# 103184                     842.0                         294.0
# 103185                     820.0                         334.0
# 103186                     806.0                         394.0
# 103187                       NaN                           NaN
#
#         zone_3_rtl_pedestrians_count  zone_3_adult_pedestrians_count  \
# 88388                         1700.0                          2824.0
# 88389                         1607.0                          2592.0
# 88390                         1210.0                          2249.0
# 88391                            NaN                             NaN
# 88392                         1390.0                          2259.0
# ...                              ...                             ...
# 103183                           NaN                             NaN
# 103184                         548.0                           842.0
# 103185                         486.0                           819.0
# 103186                         412.0                           788.0
# 103187                           NaN                             NaN
#
#         zone_3_child_pedestrians_count  zone_99_pedestrians_count  \
# 88388                             17.0                        NaN
# 88389                              6.0                        NaN
# 88390                             19.0                        NaN
# 88391                              NaN                        NaN
# 88392                             18.0                        NaN
# ...                                ...                        ...
# 103183                             NaN                        NaN
# 103184                             0.0                        NaN
# 103185                             1.0                        NaN
# 103186                            18.0                        NaN
# 103187                             NaN                        NaN
#
#         zone_99_ltr_pedestrians_count  zone_99_rtl_pedestrians_count  \
# 88388                             NaN                            NaN
# 88389                             NaN                            NaN
# 88390                             NaN                            NaN
# 88391                             NaN                            NaN
# 88392                             NaN                            NaN
# ...                               ...                            ...
# 103183                            NaN                            NaN
# 103184                            NaN                            NaN
# 103185                            NaN                            NaN
# 103186                            NaN                            NaN
# 103187                            NaN                            NaN
#
#         zone_99_adult_pedestrians_count  zone_99_child_pedestrians_count
# 88388                               NaN                              NaN
# 88389                               NaN                              NaN
# 88390                               NaN                              NaN
# 88391                               NaN                              NaN
# 88392                               NaN                              NaN
# ...                                 ...                              ...
# 103183                              NaN                              NaN
# 103184                              NaN                              NaN
# 103185                              NaN                              NaN
# 103186                              NaN                              NaN
# 103187                              NaN                              NaN
#
# [936 rows x 38 columns]

# %% [markdown]
# ### Gruppieren und summieren der relevanten Spalten nach Standort

# %%
data = data.groupby(['location_name'], as_index=False)[[
    'pedestrians_count',
]].sum()
data
# Out:
#             location_name  pedestrians_count
# 0  Bahnhofstrasse (Mitte)             705130
# 1   Bahnhofstrasse (Nord)             567071
# 2    Bahnhofstrasse (Süd)             453965
# 3        Lintheschergasse             223586

# %% [markdown]
# ### Spalten umbenennen als Vorbereitung für das Diagramm

# %%
data = data.rename(columns={
    'location_name': 'Standort',
    'pedestrians_count': 'Anzahl Passanten',
})
data
# Out:
#                  Standort  Anzahl Passanten
# 0  Bahnhofstrasse (Mitte)            705130
# 1   Bahnhofstrasse (Nord)            567071
# 2    Bahnhofstrasse (Süd)            453965
# 3        Lintheschergasse            223586

# %% [markdown]
# ## Definition des Diagrammes

# %%
import altair as alt

bar_width = 80
bar_spacing = 0.4 * bar_width
chart_height = 400

chart = alt.Chart(data).mark_bar(size=bar_width).encode(
    x=alt.X(
        'Standort:N',
        sort=['Bahnhofstrasse (Nord)', 'Bahnhofstrasse (Mitte)', 'Bahnhofstrasse (Süd)', 'Lintheschergasse'],
    ).axis(
        labelAngle=-45,
        labelOffset=bar_width / 4,
    ), 
    y=alt.Y('Anzahl Passanten:Q').axis(
        format='~s',
        tickCount=7,
    ),
    tooltip=[
        alt.Tooltip('Anzahl Passanten', format=','),
    ],
).properties(
    width={'step': bar_width + bar_spacing},
    height=chart_height
).configure_axis(
    titleFontSize=17, 
    labelFontSize=15,
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Generieren der Spec für die Darstellung des Diagrammes

# %%
import json

# In Dictionary umwandeln
spec = chart.to_dict()

# Dataset umbenennen in "values" für einfacheren Zugriff im Frontend
new_name = 'values'
old_name = spec['data']['name']
spec['data']['name'] = new_name
spec['datasets'][new_name] = spec['datasets'].pop(old_name)

# Spec in eine Datei schreiben
with open('erkundung.json', 'w') as f:
    json.dump(spec, f, indent=2)
